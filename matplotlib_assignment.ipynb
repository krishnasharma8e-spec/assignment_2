# %%
import matplotlib.pyplot as plt
import numpy as np

x = [1, 2, 3, 4, 5]
y = [10, 15, 25, 30, 50]

plt.plot(x, y)
plt.title("Simple Line Plot")
plt.xlabel("X Values")
plt.ylabel("Y Values")
plt.grid(True)

plt.show()

# %%
students = ['John', 'Jane', 'Alice', 'Bob']
marks = [75, 85, 60, 90]

plt.bar(students, marks, color=['blue', 'green', 'orange', 'red'])
plt.title("Marks Scored by Students")
plt.xlabel("Students")
plt.ylabel("Marks")
plt.show()

# %%
regions = ['North America', 'Europe', 'Asia', 'Others']
revenue = [45, 25, 20, 10]

explode = [0.1, 0, 0, 0]
plt.pie(revenue, labels=regions, autopct='%1.1f%%', explode=explode)
plt.title("Revenue Distribution by Region")
plt.show()
#This will show a pie chart with North America slightly separated (highlighted) because it has the highest revenue.

# %%
data = np.random.randint(1, 101, 1000)

plt.hist(data, bins=10,rwidth=0.9)
plt.title("Histogram of Random Integers (1–100)")
plt.xlabel("Value Range")
plt.ylabel("Frequency")
plt.show()
